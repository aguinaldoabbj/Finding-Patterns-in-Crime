# %% [markdown]
# # Universidade Federal do Rio Grande do Norte
# ## Programa de Pós-graduação em Engenharia Elétrica e de Computação
# ### Course: Tópicos Especiais C
# ### Professor: Ivanovitch Silva
# ### Students:
# * Aguinaldo Bezerra Batista Júnior
# * Pedro Klisley Ferreira da Silva
# * Ycaro Ravel Dantas
#
# #### Activity: Task 2, Project 1
# #### Subject: Finding Patterns in Crime
# #### Objectives: Perform data analysis of a given dataset following guidance and hints in the professor's notebook.
# #### Dataset: MontgomeryCountyCrime2013.csv

# %% [markdown]
# # 1 Getting to know the proposed dataset

# %% [markdown]
# Loading the given dataset into Pandas object and showing some rows

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

crimes = pd.read_csv("MontgomeryCountyCrime2013.csv")
crimes.head()
# Out:
#    Incident ID  CR Number    Dispatch Date / Time  Class  \
# 0    200939101   13047006  10/02/2013 07:52:41 PM    511
# 1    200952042   13062965  12/31/2013 09:46:58 PM   1834
# 2    200926636   13031483  07/06/2013 09:06:24 AM   1412
# 3    200929538   13035288  07/28/2013 09:13:15 PM   2752
# 4    200930689   13036876  08/06/2013 05:16:17 PM   2812
#
#                      Class Description Police District Name  \
# 0                 BURG FORCE-RES/NIGHT                OTHER
# 1           CDS-POSS MARIJUANA/HASHISH           GERMANTOWN
# 2              VANDALISM-MOTOR VEHICLE   MONTGOMERY VILLAGE
# 3  FUGITIVE FROM JUSTICE(OUT OF STATE)             BETHESDA
# 4          DRIVING UNDER THE INFLUENCE             BETHESDA
#
#          Block Address           City State  Zip Code      ...       Sector  \
# 0  25700  MT RADNOR DR       DAMASCUS    MD   20872.0      ...          NaN
# 1   GUNNERS BRANCH  RD     GERMANTOWN    MD   20874.0      ...            M
# 2      OLDE TOWNE  AVE   GAITHERSBURG    MD   20877.0      ...            P
# 3            BEACH  DR    CHEVY CHASE    MD   20815.0      ...            D
# 4            BEACH  DR  SILVER SPRING    MD   20815.0      ...            D
#
#   Beat    PRA       Start Date / Time  End Date / Time Latitude Longitude  \
# 0  NaN    NaN  10/02/2013 07:52:00 PM              NaN      NaN       NaN
# 1  5M1  470.0  12/31/2013 09:46:00 PM              NaN      NaN       NaN
# 2  6P3  431.0  07/06/2013 09:06:00 AM              NaN      NaN       NaN
# 3  2D1   11.0  07/28/2013 09:13:00 PM              NaN      NaN       NaN
# 4  2D3  178.0  08/06/2013 05:16:00 PM              NaN      NaN       NaN
#
#    Police District Number  Location Address Number
# 0                   OTHER       NaN        25700.0
# 1                      5D       NaN            NaN
# 2                      6D       NaN            NaN
# 3                      2D       NaN            NaN
# 4                      2D       NaN            NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# Listing the columns of the dataset and their types

# %%
crimes.columns
# Out:
# Index(['Incident ID', 'CR Number', 'Dispatch Date / Time', 'Class',
#        'Class Description', 'Police District Name', 'Block Address', 'City',
#        'State', 'Zip Code', 'Agency', 'Place', 'Sector', 'Beat', 'PRA',
#        'Start Date / Time', 'End Date / Time', 'Latitude', 'Longitude',
#        'Police District Number', 'Location', 'Address Number'],
#       dtype='object')

# %%
crimes.dtypes
# Out:
# Incident ID                 int64
# CR Number                   int64
# Dispatch Date / Time       object
# Class                       int64
# Class Description          object
# Police District Name       object
# Block Address              object
# City                       object
# State                      object
# Zip Code                  float64
# Agency                     object
# Place                      object
# Sector                     object
# Beat                       object
# PRA                       float64
# Start Date / Time          object
# End Date / Time            object
# Latitude                  float64
# Longitude                 float64
# Police District Number     object
# Location                   object
# Address Number            float64
# dtype: object

# %% [markdown]
# Making some descriptive statistics over the dataset:

# %%
crimes.describe()
# Out:
#         Incident ID     CR Number         Class      Zip Code           PRA  \
# count  2.336900e+04  2.336900e+04  23369.000000  23339.000000  23363.000000
# mean   2.009394e+08  1.307173e+07   1555.058881  20876.146750    347.631511
# std    7.880707e+03  2.131680e+06    956.776909     30.786484    188.519015
# min    2.009222e+08  1.303055e+07    111.000000  20707.000000      0.000000
# 25%    2.009327e+08  1.303909e+07    624.000000  20852.000000    180.500000
# 50%    2.009394e+08  1.304698e+07   1412.000000  20878.000000    354.000000
# 75%    2.009459e+08  1.305508e+07   2738.000000  20903.000000    479.000000
# max    2.010701e+08  2.013030e+08   3240.000000  21771.000000    808.000000
#
#            Latitude     Longitude  Address Number
# count  23208.000000  23208.000000    23237.000000
# mean      39.080484    -77.112534     8176.871455
# std        0.069195      0.096437     6539.953102
# min       38.941466    -77.516909        1.000000
# 25%       39.025947    -77.194657     1600.000000
# 50%       39.075279    -77.103545     8300.000000
# 75%       39.141912    -77.032340    12400.000000
# max       39.342574    -76.909283    39000.000000

# %% [markdown]
# By inspecting column names and some cells, we figured out some relations between some columns. Columns **"Police Distric Name"** and **"Police District Number"** stand for the same information: the identification of the Police District (Name or Code). Similarly, columns **"Class"** and **"Class Description"** refer to crime classes codes and their descriptions. **"Location"** is clearly a join of the information on **"Latitude"** and **"Longitude" columns**. A quick google search allowed to perceive the meaning of remaining non self-explanatory columns. **"CR Number"** refers to the Police Report Number, **"Beat"** stands for a police patrol area (subset of a Sector) and **"PRA"**, the Police Response Area, is a subset of Beat.

# %% [markdown]
# The column **"Zip Code"**, as already pointed in the guidance notebook, contains wrong type data. It is important to convert wrong or inadequate type data to more appropriate ones to help further analysis.

# %% [markdown]
# We could convert data in the **"Zip Code"** and **"Address Number"** columns to the more suitable interger type. However, these columns are plenty of _NaN_ and the lack of _NaN_ and _NA_ representations in integer columns is a well known Pandas "gotcha". Maybe thats why these columns were built as float type data (compatible with NAs and NaNs). A workaround to this problem could be the definition of a sentinel interger values for this kind of data absense.

# %% [markdown]
# We can account the occurence of NaNs and NAs:

# %%
crimes.isnull().sum()
# Out:
# Incident ID                   0
# CR Number                     0
# Dispatch Date / Time          0
# Class                         0
# Class Description             0
# Police District Name          0
# Block Address                 0
# City                          0
# State                         0
# Zip Code                     30
# Agency                        0
# Place                         0
# Sector                       46
# Beat                          8
# PRA                           6
# Start Date / Time             0
# End Date / Time           10178
# Latitude                    161
# Longitude                   161
# Police District Number        0
# Location                    161
# Address Number              132
# dtype: int64

# %% [markdown]
# NaNs and NAs are likeky to happen in a dataset during data acquisition, transmission and conversion steps.
# They negatively affect the quality of the dataset and they should be carefuly spotted and evaluated, as they may
# lead to weak or innacurate conclusions.

# %% [markdown]
# # 2 Preparing Data

# %% [markdown]
# Converting Date/Time data in columns **"Dispatch Date / Time"**, **"Start Date / Time"** and **"End Date / Time"**
# from a generic Pandas object to a more convinient Date/Time Pandas object. This will allow the further extraction of date and time components easily. The resulting converted columns are going to be added right next to the original data columns.

# %%
crimes.insert(3, "datetime_Dispatch", pd.to_datetime(crimes["Dispatch Date / Time"]))

# %%
crimes.insert(17, "datetime_Start", pd.to_datetime(crimes["Start Date / Time"]))

# %%
crimes.insert(19, "datetime_End", pd.to_datetime(crimes["End Date / Time"]))

# %%
crimes.head()
# Out:
#    Incident ID  CR Number    Dispatch Date / Time   datetime_Dispatch  Class  \
# 0    200939101   13047006  10/02/2013 07:52:41 PM 2013-10-02 19:52:41    511
# 1    200952042   13062965  12/31/2013 09:46:58 PM 2013-12-31 21:46:58   1834
# 2    200926636   13031483  07/06/2013 09:06:24 AM 2013-07-06 09:06:24   1412
# 3    200929538   13035288  07/28/2013 09:13:15 PM 2013-07-28 21:13:15   2752
# 4    200930689   13036876  08/06/2013 05:16:17 PM 2013-08-06 17:16:17   2812
#
#                      Class Description Police District Name  \
# 0                 BURG FORCE-RES/NIGHT                OTHER
# 1           CDS-POSS MARIJUANA/HASHISH           GERMANTOWN
# 2              VANDALISM-MOTOR VEHICLE   MONTGOMERY VILLAGE
# 3  FUGITIVE FROM JUSTICE(OUT OF STATE)             BETHESDA
# 4          DRIVING UNDER THE INFLUENCE             BETHESDA
#
#          Block Address           City State      ...          PRA  \
# 0  25700  MT RADNOR DR       DAMASCUS    MD      ...          NaN
# 1   GUNNERS BRANCH  RD     GERMANTOWN    MD      ...        470.0
# 2      OLDE TOWNE  AVE   GAITHERSBURG    MD      ...        431.0
# 3            BEACH  DR    CHEVY CHASE    MD      ...         11.0
# 4            BEACH  DR  SILVER SPRING    MD      ...        178.0
#
#         Start Date / Time      datetime_Start End Date / Time datetime_End  \
# 0  10/02/2013 07:52:00 PM 2013-10-02 19:52:00             NaN          NaT
# 1  12/31/2013 09:46:00 PM 2013-12-31 21:46:00             NaN          NaT
# 2  07/06/2013 09:06:00 AM 2013-07-06 09:06:00             NaN          NaT
# 3  07/28/2013 09:13:00 PM 2013-07-28 21:13:00             NaN          NaT
# 4  08/06/2013 05:16:00 PM 2013-08-06 17:16:00             NaN          NaT
#
#    Latitude Longitude Police District Number Location Address Number
# 0       NaN       NaN                  OTHER      NaN        25700.0
# 1       NaN       NaN                     5D      NaN            NaN
# 2       NaN       NaN                     6D      NaN            NaN
# 3       NaN       NaN                     2D      NaN            NaN
# 4       NaN       NaN                     2D      NaN            NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# Our dataset contains a list of crimes registered between the months of july and december in 2013. Now that we have the columns in the appropriate format, we can sort the values by date. Using the column **'Dispatch Date / Time'**:

# %%
crimes.sort_values('Dispatch Date / Time').head()
# Out:
#     Incident ID  CR Number    Dispatch Date / Time   datetime_Dispatch  Class  \
# 18    200925991   13030553  07/01/2013 01:03:17 AM 2013-07-01 01:03:17   2812
# 15    200925984   13030556  07/01/2013 01:25:48 AM 2013-07-01 01:25:48   2623
# 63    200926057   13030657  07/01/2013 01:29:14 PM 2013-07-01 13:29:14    617
# 65    200926059   13030660  07/01/2013 01:29:22 PM 2013-07-01 13:29:22   2938
# 72    200926068   13030662  07/01/2013 01:39:35 PM 2013-07-01 13:39:35   1014
#
#                   Class Description Police District Name      Block Address  \
# 18      DRIVING UNDER THE INFLUENCE        SILVER SPRING  8700  PLYMOUTH ST
# 15  SUICIDE-ATTEMPT-POISON/OVERDOSE        SILVER SPRING     2200  CLARK PL
# 63  LARCENY FROM BUILDING OVER $200        SILVER SPRING    8200  FENTON ST
# 65                  POL INFORMATION   MONTGOMERY VILLAGE    700  CLOPPER RD
# 72         FORGERY/CNTRFT-ALL OTHER             BETHESDA  9800  MONTAUK AVE
#
#              City State      ...          PRA       Start Date / Time  \
# 18  SILVER SPRING    MD      ...        126.0  07/01/2013 01:03:00 AM
# 15  SILVER SPRING    MD      ...        175.0  07/01/2013 01:25:00 AM
# 63  SILVER SPRING    MD      ...         93.0  06/28/2013 04:45:00 PM
# 65   GAITHERSBURG    MD      ...        555.0  06/28/2013 06:00:00 PM
# 72       BETHESDA    MD      ...        194.0  06/24/2013 01:00:00 PM
#
#         datetime_Start         End Date / Time        datetime_End   Latitude  \
# 18 2013-07-01 01:03:00                     NaN                 NaT  38.999406
# 15 2013-07-01 01:25:00                     NaN                 NaT  39.017814
# 63 2013-06-28 16:45:00                     NaN                 NaT  38.991743
# 65 2013-06-28 18:00:00  06/28/2013 07:00:00 PM 2013-06-28 19:00:00  39.143717
# 72 2013-06-24 13:00:00  07/01/2013 01:00:00 PM 2013-07-01 13:00:00  39.016598
#
#     Longitude Police District Number  \
# 18 -77.007736                     3D
# 15 -77.047689                     3D
# 63 -77.024043                     3D
# 65 -77.223842                     6D
# 72 -77.129364                     2D
#
#                                      Location Address Number
# 18  (38.999406266117461, -77.007735832110484)         8700.0
# 15   (39.017814078946948, -77.04768926351224)         2200.0
# 63   (38.991742503465268, -77.02404349079022)         8200.0
# 65    (39.143716826007477, -77.2238423722319)          700.0
# 72  (39.016598405561517, -77.129363757226471)         9800.0
#
# [5 rows x 25 columns]

# %% [markdown]
# And using the column **'Start Date / Time'**:

# %%
crimes.sort_values('Start Date / Time').head()
# Out:
#        Incident ID  CR Number    Dispatch Date / Time   datetime_Dispatch  \
# 10484    200938024   13045759  09/25/2013 08:27:18 PM 2013-09-25 20:27:18
# 20891    200949682   13060292  12/16/2013 07:39:31 AM 2013-12-16 07:39:31
# 8638     200935931   13040835  08/29/2013 11:56:45 AM 2013-08-29 11:56:45
# 10646    200938204   13033703  07/19/2013 11:13:47 AM 2013-07-19 11:13:47
# 4028     200930688   13036892  08/06/2013 06:58:05 PM 2013-08-06 18:58:05
#
#        Class             Class Description Police District Name  \
# 10484   2013  FAMILY OFFENSE - ABUSE/CHILD        SILVER SPRING
# 20891   2013  FAMILY OFFENSE - ABUSE/CHILD           GERMANTOWN
# 8638    2013  FAMILY OFFENSE - ABUSE/CHILD              WHEATON
# 10646   2013  FAMILY OFFENSE - ABUSE/CHILD            ROCKVILLE
# 4028    2013  FAMILY OFFENSE - ABUSE/CHILD            ROCKVILLE
#
#               Block Address           City State      ...          PRA  \
# 10484    9200  KINGSBURY DR  SILVER SPRING    MD      ...        117.0
# 20891  19000  HIGHSTREAM DR     GERMANTOWN    MD      ...        596.0
# 8638   12700  VEIRS MILL RD      ROCKVILLE    MD      ...        339.0
# 10646         800  BOWIE RD      ROCKVILLE    MD      ...        260.0
# 4028       7300  CALHOUN PL      ROCKVILLE    MD      ...        281.0
#
#             Start Date / Time      datetime_Start         End Date / Time  \
# 10484  01/01/1985 06:00:00 AM 1985-01-01 06:00:00  12/31/1990 11:30:00 PM
# 20891  01/01/1997 12:01:00 AM 1997-01-01 00:01:00  12/31/1998 11:59:00 PM
# 8638   01/01/1999 01:01:00 AM 1999-01-01 01:01:00  12/31/2001 01:01:00 AM
# 10646  01/01/2001 01:00:00 AM 2001-01-01 01:00:00  12/31/2011 12:00:00 AM
# 4028   01/01/2001 12:00:00 AM 2001-01-01 00:00:00  12/31/2003 12:00:00 AM
#
#              datetime_End   Latitude  Longitude Police District Number  \
# 10484 1990-12-31 23:30:00  39.004660 -77.021851                     3D
# 20891 1998-12-31 23:59:00  39.170986 -77.286440                     5D
# 8638  2001-12-31 01:01:00  39.064558 -77.097191                     4D
# 10646 2011-12-31 00:00:00  39.074956 -77.149421                     1D
# 4028  2003-12-31 00:00:00  39.107938 -77.148110                     1D
#
#                                         Location Address Number
# 10484  (39.004660203241308, -77.021851401891453)         9200.0
# 20891   (39.170985984960303, -77.28644024756737)        19000.0
# 8638   (39.064557709468289, -77.097190838951619)        12700.0
# 10646   (39.074956028321907, -77.14942069804772)          800.0
# 4028   (39.107938144546871, -77.148110003940658)         7300.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 3 Analyzing the times of crimes

# %% [markdown]
# For making assumptions about dates and times of crimes, we have to look deeper in to the Date/Time columns
# we had just converted to a convinient datetime format from Pandas. By this conversion, it is possible to access all  the building parts of Date/Time informations (date, time, day, month, hour, minute, etc.) and make interesting computations.

# %% [markdown]
# A careful look into the Date/Time columns makes us conclude that **"Start Date / Time"** referes to the date/time when the police was contacted. So, this time is the closest to the actual time of the occurrence. **"Dispatch Date / Time"** always points to a time shortly after the time of occurrence and referes to the time when a police team was dispatched to the occurrence location.

# %% [markdown]
# First, for explanatory analysis, we can count the number of crimes dispatched each day and the number of crimes started each day and see it over the time.

# %%
crimes['number_of_crimes']=1
crimes['datetime_Dispatch_date']=crimes['datetime_Dispatch'].dt.date
crimes.groupby(by='datetime_Dispatch_date',as_index=False).sum()[['datetime_Dispatch_date','number_of_crimes']].plot(x='datetime_Dispatch_date', y='number_of_crimes')

# %%
crimes['number_of_crimes']=1
crimes['datetime_Start_date']=crimes['datetime_Start'].dt.date
crimes.groupby(by='datetime_Start_date',as_index=False).sum()[['datetime_Start_date','number_of_crimes']].plot(x='datetime_Start_date', y='number_of_crimes')

# %% [markdown]
# As we can see, while the "Dispatch Date / Time" column contains only dates in 2013, the "Start Date / Time" column contains dates from a broader interval. Let's take a look:

# %%
# 5 first values of 'Dispatch Date / Time' column, sorted by date
crimes.sort_values('datetime_Dispatch_date')['Dispatch Date / Time'].head()
# Out:
# 90    07/01/2013 06:01:04 PM
# 94    07/01/2013 06:16:56 PM
# 93    07/01/2013 04:21:33 PM
# 92    07/01/2013 05:37:49 PM
# 91    07/01/2013 03:22:15 PM
# Name: Dispatch Date / Time, dtype: object

# %%
# 5 first values of 'Dispatch Date / Time' column, sorted (descending order) by date
crimes.sort_values('datetime_Dispatch_date',ascending=False)['Dispatch Date / Time'].head()
# Out:
# 22876    12/31/2013 07:16:38 PM
# 22906    12/31/2013 01:44:20 PM
# 22920    12/31/2013 05:29:13 PM
# 22774    12/31/2013 12:29:00 AM
# 22775    12/31/2013 01:58:13 AM
# Name: Dispatch Date / Time, dtype: object

# %%
# 5 first values of 'Dispatch Date / Time' and 'Class Description' columns, sorted by date
crimes.sort_values('datetime_Start_date')[['Start Date / Time','Class Description']].head()
# Out:
#             Start Date / Time             Class Description
# 15953  10/30/1974 12:00:00 AM  FAMILY OFFENSE - ABUSE/CHILD
# 17470  02/11/1977 12:00:00 AM  FAMILY OFFENSE - ABUSE/CHILD
# 23313  08/24/1980 12:00:00 AM  FAMILY OFFENSE - ABUSE/CHILD
# 10484  01/01/1985 06:00:00 AM  FAMILY OFFENSE - ABUSE/CHILD
# 17461  08/27/1993 12:00:00 AM  FAMILY OFFENSE - ABUSE/CHILD

# %%
# 5 first values of 'Dispatch Date / Time' and 'Class Description' columns, sorted (descending order) by date
crimes.sort_values('datetime_Start_date', ascending=False)[['Start Date / Time','Class Description']].head()
# Out:
#             Start Date / Time               Class Description
# 23323  01/25/2014 03:00:00 PM   EX PARTE/PROTECT. ORDER VIOL.
# 22925  12/31/2013 05:15:00 AM         BURG FORCE-RES/TIME UNK
# 22852  12/31/2013 01:51:00 PM  LARCENY SHOPLIFTING $50 - $199
# 22855  12/31/2013 01:33:00 AM             SIMPLE ASSAULT - PO
# 22856  12/31/2013 03:24:00 PM            SUDDEN DEATH NATURAL

# %% [markdown]
# The "Start Date / Time" column contains dates from the 70's, 80's, 90's and even one in 2014. Although we can have crimes committed a long time ago and denounced only in 2013, the exact date and time of this old crimes are uncertain. As we can see, most of them were registered with Start Date in the first day of the month and a rounded Time. So, for our analysis about the dates and times of the crimes, let's consider only the crimes started between July and December 2013. For that, we will create a "window" in the dataset.

# %%
from datetime import datetime
crimes_window = crimes[(crimes['datetime_Start_date']>=datetime.strptime('Jul 01 2013','%b %d %Y').date()) & (crimes['datetime_Start_date']<=datetime.strptime('Dec 31 2013','%b %d %Y').date())]
print(crimes.shape)
print(crimes_window.shape)
# Out:
# (23369, 28)
# (22530, 28)

# %% [markdown]
# So, now we can easily figure out what day of the week are the most crimes committed on:

# %%
print("\tNumber of Crimes by Weekday")
print(crimes_window.datetime_Start.dt.weekday_name.value_counts())
print("\n\tPercentage of Crimes by Weekday")
print(crimes_window.datetime_Start.dt.weekday_name.value_counts(normalize=True))
# Out:
# 	Number of Crimes by Weekday
# Friday       3584
# Tuesday      3354
# Wednesday    3301
# Thursday     3243
# Saturday     3204
# Monday       3036
# Sunday       2808
# Name: datetime_Start, dtype: int64
#
# 	Percentage of Crimes by Weekday
# Friday       0.159077
# Tuesday      0.148868
# Wednesday    0.146516
# Thursday     0.143941
# Saturday     0.142210
# Monday       0.134754
# Sunday       0.124634
# Name: datetime_Start, dtype: float64

# %%
weekdays_crimes = pd.Categorical(crimes_window.datetime_Start.dt.weekday_name, categories=['Sunday', 'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'], ordered=True).value_counts()
weekdays_crimes.plot(ylim=[2000,4000],title="Number of Crimes by Weekday")

# %% [markdown]
# By this day of week crime ranking we can say that **Friday** is the day that most crimes occurred.

# %% [markdown]
# As the datetime object of Pandas does not provide time in part of day format (morning, afternoon, etc.), we could
# write a little function to map the time crimes occur in part of day strings:

# %%
from datetime import time
from datetime import datetime

morning_start = time(6)
afternoon_start = time(12)
evening_start = time(18)
evening_end = time(23,59)
dawn_start = time(0)

def part_of_day(t):
    if morning_start <= t < afternoon_start:
        return 'morning'
    if afternoon_start <= t < evening_start:
        return 'afternoon'
    if evening_start <= t <= evening_end:
        return 'evening'
    if dawn_start <= t < morning_start:
        return 'dawn'
    
    return 'unknown'

# %% [markdown]
# And apply it to the **"datetime_Start"** column, placing the results as a new column of the dataset.

# %%
crimes_window['crimes_period'] = crimes_window.datetime_Start.dt.time.apply(part_of_day)
crimes_window[['datetime_Start','crimes_period']].head()
# Out:
#        datetime_Start crimes_period
# 0 2013-10-02 19:52:00       evening
# 1 2013-12-31 21:46:00       evening
# 2 2013-07-06 09:06:00       morning
# 3 2013-07-28 21:13:00       evening
# 4 2013-08-06 17:16:00     afternoon

# %% [markdown]
# From this little computation, it is possible to discover what time of day are the most crimes committed:

# %%
print("\tNumber of Crimes by Period of the Day")
print(crimes_window.crimes_period.value_counts())
print("\n\tPercentage of Crimes by Period of the Day")
print(crimes_window.crimes_period.value_counts(normalize=True))
# Out:
# 	Number of Crimes by Period of the Day
# evening      7521
# afternoon    6843
# dawn         4284
# morning      3882
# Name: crimes_period, dtype: int64
#
# 	Percentage of Crimes by Period of the Day
# evening      0.333822
# afternoon    0.303728
# dawn         0.190146
# morning      0.172304
# Name: crimes_period, dtype: float64

# %%
crimes_periods = pd.Categorical(crimes_window.crimes_period, categories=['dawn', 'morning','afternoon','evening'], ordered=True).value_counts()
crimes_periods.plot(ylim=[2000,8000],title="Number of Crimes by Period of the Day")

# %% [markdown]
# Not surprisingly, the time of the day most crimes occurred is the **evening**.

# %% [markdown]
# Similarly, we can point out which month crimes were more likely to occur in 2013:

# %%
print("\tNumber of Crimes by Month")
print(crimes_window.datetime_Start.dt.strftime('%b').value_counts())
print("\n\tPercentage of Crimes by Month")
print(crimes_window.datetime_Start.dt.strftime('%b').value_counts(normalize=True))
# Out:
# 	Number of Crimes by Month
# Oct    3963
# Aug    3941
# Sep    3857
# Nov    3808
# Dec    3532
# Jul    3429
# Name: datetime_Start, dtype: int64
#
# 	Percentage of Crimes by Month
# Oct    0.175899
# Aug    0.174922
# Sep    0.171194
# Nov    0.169019
# Dec    0.156769
# Jul    0.152197
# Name: datetime_Start, dtype: float64

# %%
month_crimes = pd.Categorical(crimes_window.datetime_Start.dt.strftime('%b'), categories=['Jul','Aug','Sep','Oct','Nov','Dec'], ordered=True).value_counts()
month_crimes.plot(kind='bar',ylim=[2000,4000],title="Number of Crimes by Month")

# %% [markdown]
# So, **October** was the most quantitatively violent month.

# %% [markdown]
# If we count the numbers of crimes committed each day, we can also see the less and the most violent days of the semester.

# %%
print("Crimes Commited Each Day")
crimes_window.groupby(by='datetime_Start_date',as_index=False).sum()[['datetime_Start_date', 'number_of_crimes']].describe()
# Out:
# Crimes Commited Each Day
#        number_of_crimes
# count        184.000000
# mean         122.445652
# std           19.452823
# min           67.000000
# 25%          110.000000
# 50%          123.000000
# 75%          136.000000
# max          169.000000

# %%
print("Less Violent Days of the Semester")
crimes_startcount = crimes_window.groupby(by='datetime_Start_date',as_index=False).sum()[['datetime_Start_date', 'number_of_crimes']]
crimes_startcount.insert(1, "weekday", pd.to_datetime(crimes_startcount.datetime_Start_date).dt.weekday_name)
crimes_startcount.sort_values('number_of_crimes').head(10)
# Out:
# Less Violent Days of the Semester
#     datetime_Start_date    weekday  number_of_crimes
# 177          2013-12-25  Wednesday                67
# 161          2013-12-09     Monday                76
# 160          2013-12-08     Sunday                81
# 182          2013-12-30     Monday                83
# 153          2013-12-01     Sunday                83
# 183          2013-12-31    Tuesday                84
# 6            2013-07-07     Sunday                86
# 3            2013-07-04   Thursday                87
# 178          2013-12-26   Thursday                87
# 20           2013-07-21     Sunday                87

# %%
print("Most Violent Days of the Semester")
crimes_startcount.sort_values('number_of_crimes',ascending=False).head(10)
# Out:
# Most Violent Days of the Semester
#     datetime_Start_date    weekday  number_of_crimes
# 81           2013-09-20     Friday               169
# 157          2013-12-05   Thursday               162
# 123          2013-11-01     Friday               162
# 149          2013-11-27  Wednesday               161
# 172          2013-12-20     Friday               161
# 145          2013-11-23   Saturday               161
# 32           2013-08-02     Friday               160
# 65           2013-09-04  Wednesday               160
# 109          2013-10-18     Friday               159
# 165          2013-12-13     Friday               159

# %% [markdown]
# While the average number of crimes per day is 122 in the semester, the Christmas of 2013 had 67 crimes registered. Among the 10 less violent days we also have another holliday, the 4th July, and the last two days of the year.

# %% [markdown]
# # 4 Analyzing locations of crimes
#
# There are a few columns that encode information about the location of crimes:
#
# - <span style="background-color: #F9EBEA; color:##C0392B">Police District Name</span>
# - <span style="background-color: #F9EBEA; color:##C0392B">Block Address</span>
# - <span style="background-color: #F9EBEA; color:##C0392B">Zip Code</span>
# - <span style="background-color: #F9EBEA; color:##C0392B">Sector</span>
# - <span style="background-color: #F9EBEA; color:##C0392B">Beat</span>
# - <span style="background-color: #F9EBEA; color:##C0392B">Latitude</span>
# - <span style="background-color: #F9EBEA; color:##C0392B">Longitude</span>
# - <span style="background-color: #F9EBEA; color:##C0392B">Police District Number</span>
# - <span style="background-color: #F9EBEA; color:##C0392B">Location</span>
# - <span style="background-color: #F9EBEA; color:##C0392B">Address Number</span>

# %%
location_columns = ['Police District Name','Block Address','Zip Code','Sector','Beat',
                    'Latitude','Longitude','Police District Number','Location',
                    'Address Number']

# %% [markdown]
# These columns have varying numbers of missing values, and varying granularity. Some of the columns represent areas with large granularity (like police districts), whereas some represent areas with small granularity, like <span style="background-color: #F9EBEA; color:##C0392B">Latitude</span>, and <span style="background-color: #F9EBEA; color:##C0392B">Longitude</span>.
#
#
# In order to decide which column to use to analyze the locations of crimes, you need to utilize the following criteria:
#
# - **Granularity**. Areas that are too small aren't great, because only a few crimes were committed inside them, which makes it hard to analyze and compare. For example, if I tell you that Silver Spring (a city in Montgomery County) is the place with the most crimes, you'll know to avoid that area. However, if I tell you that a 100 foot section of Silver Spring has the most crimes, it won't be as helpful (it's unlikely that you'll ever be in that 100 foot section).

# %%
for column in location_columns:
    count = crimes[column].value_counts().count()
    print(column, ": ", count)
# Out:
# Police District Name :  8
# Block Address :  8143
# Zip Code :  49
# Sector :  15
# Beat :  42
# Latitude :  8065
# Longitude :  8065
# Police District Number :  8
# Location :  8065
# Address Number :  286

# %%
pol_dist_relation = crimes.groupby(["Police District Name"])["Police District Number"].value_counts()
print(pol_dist_relation)
# Out:
# Police District Name  Police District Number
# BETHESDA              2D                        3383
# GERMANTOWN            5D                        2755
# MONTGOMERY VILLAGE    6D                        3812
# OTHER                 OTHER                        8
# ROCKVILLE             1D                        3480
# SILVER SPRING         3D                        5533
# TAKOMA PARK           TPPD                        23
# WHEATON               4D                        4375
# Name: Police District Number, dtype: int64

# %% [markdown]
# We will check the granularity of the columns by the different values count of each column.
# Limiting to variables with less than 50 different values, we will got these variables:
#
# - Police District Name :  8
# - Zip Code :  49
# - Sector :  15
# - Beat :  42
# - Police District Number :  8
#
# From this analysis, the **Police District Name** and **Police District Number** are the variables with the best granularity for this problem, since both have few different values, but not too few.

# %% [markdown]
# - **Comprehensibility**. You looked up the Police District map of Montgomery County before, so it's simple to tell what area corresponds to district <span style="background-color: #F9EBEA; color:##C0392B">6</span>. However, what area does Beat <span style="background-color: #F9EBEA; color:##C0392B">5M1</span> correspond to? You may be able to look this up, but it's harder to comprehend.

# %%
for column in location_columns:
    result = crimes[column].value_counts().head().index
    print(column, ": ", result)
# Out:
# Police District Name :  Index(['SILVER SPRING', 'WHEATON', 'MONTGOMERY VILLAGE', 'ROCKVILLE',
#        'BETHESDA'],
#       dtype='object')
# Block Address :  Index(['11100  VEIRS MILL RD', '700  RUSSELL AVE', '100  EDISON PARK DR',
#        '7100  DEMOCRACY BLVD', '12000  CHERRY HILL RD'],
#       dtype='object')
# Zip Code :  Float64Index([20910.0, 20904.0, 20902.0, 20877.0, 20874.0], dtype='float64')
# Sector :  Index(['A', 'G', 'I', 'P', 'D'], dtype='object')
# Beat :  Index(['3G1', '3I1', '4L2', '1A3', '3I2'], dtype='object')
# Latitude :  Float64Index([39.0373858785, 39.1506767386, 39.111781485, 39.0219752112,
#               39.0526973055],
#              dtype='float64')
# Longitude :  Float64Index([-77.0516359828, -77.2040589532, -77.2352805179, -77.1466424589,
#               -76.9531784238],
#              dtype='float64')
# Police District Number :  Index(['3D', '4D', '6D', '1D', '2D'], dtype='object')
# Location :  Index(['(39.037385878480961, -77.051635982808946)',
#        '(39.150676738601661, -77.20405895316722)',
#        '(39.111781484977996, -77.235280517911249)',
#        '(39.02197521120231, -77.14664245887181)',
#        '(39.052697305485282, -76.953178423831446)'],
#       dtype='object')
# Address Number :  Float64Index([1.0, 100.0, 700.0, 11100.0, 800.0], dtype='float64')

# %% [markdown]
# Observing the values of these columns, the **Police District Name** is the variable tha is most comprehensible, since we can know where the facts ocurred without any mapping.

# %% [markdown]
# - **Missing values**. If a column has a lot of missing values, that means that the conclusions you draw are less valid, because you don't know if the missing data is systematic (ie all data for a given district is missing) or random (equal amounts of data are missing from each district). You should try to select a column that has minimal missing values.

# %%
#Missing values
location_columns = ['Police District Name','Block Address','Zip Code','Sector','Beat',
                    'Latitude','Longitude','Police District Number','Location',
                    'Address Number']
crimes[location_columns].isnull().sum()
# Out:
# Police District Name        0
# Block Address               0
# Zip Code                   30
# Sector                     46
# Beat                        8
# Latitude                  161
# Longitude                 161
# Police District Number      0
# Location                  161
# Address Number            132
# dtype: int64

# %% [markdown]
# Observing the missing values of these columns, the **Police District Name**, **Block address**, **Beat** and **Police District Number** are the variables with less missing values.

# %% [markdown]
# Combining the granularity, comprehensibility and missing values criteria, we choose the variable **Police District Name** because it was best evaluated on these 3 aspects.

# %% [markdown]
# After choose the location variable to use, we could answer these questions:
#
# - In what area did the most crimes occur? What physical locations (like cities) does this area correspond to?

# %%
print("Incident ID Null: ", crimes['Incident ID'].isnull().sum())

crimes_count = crimes.groupby(["Police District Name"])['Police District Number'].value_counts()
print (crimes_count.sort_values(ascending=False))
# Out:
# Incident ID Null:  0
# Police District Name  Police District Number
# SILVER SPRING         3D                        5533
# WHEATON               4D                        4375
# MONTGOMERY VILLAGE    6D                        3812
# ROCKVILLE             1D                        3480
# BETHESDA              2D                        3383
# GERMANTOWN            5D                        2755
# TAKOMA PARK           TPPD                        23
# OTHER                 OTHER                        8
# Name: Police District Number, dtype: int64

# %%
crimes.groupby(["Police District Name"])['City'].value_counts()
# Out:
# Police District Name  City
# BETHESDA              BETHESDA              1736
#                       ROCKVILLE              534
#                       CHEVY CHASE            496
#                       KENSINGTON             275
#                       POTOMAC                162
#                       SILVER SPRING          158
#                       CABIN JOHN              18
#                       GLEN ECHO                4
# GERMANTOWN            GERMANTOWN            2128
#                       DAMASCUS               229
#                       CLARKSBURG             173
#                       GAITHERSBURG           119
#                       BOYDS                   86
#                       DICKERSON                7
#                       BARNESVILLE              4
#                       MOUNT AIRY               3
#                       BROOKEVILLE              2
#                       DERWOOD                  2
#                       MONTGOMERY VILLAGE       1
#                       POOLESVILLE              1
# MONTGOMERY VILLAGE    GAITHERSBURG          2883
#                       MONTGOMERY VILLAGE     686
#                       ROCKVILLE              115
#                       DERWOOD                114
#                       WASHINGTON GROVE         6
#                       GERMANTOWN               4
#                       OLNEY                    4
# OTHER                 CHEVY CHASE              1
#                       DAMASCUS                 1
#                       GAITHERSBURG             1
#                                             ...
#                       LAUREL                   1
#                       OLNEY                    1
# ROCKVILLE             ROCKVILLE             2394
#                       GAITHERSBURG           398
#                       POTOMAC                365
#                       DERWOOD                154
#                       POOLESVILLE            104
#                       GERMANTOWN              37
#                       DICKERSON               19
#                       BOYDS                    4
#                       SILVER SPRING            3
#                       BEALLSVILLE              2
# SILVER SPRING         SILVER SPRING         5102
#                       BURTONSVILLE           304
#                       TAKOMA PARK            122
#                       SPENCERVILLE             3
#                       CHEVY CHASE              1
#                       LAUREL                   1
# TAKOMA PARK           TAKOMA PARK             19
#                       SILVER SPRING            4
# WHEATON               SILVER SPRING         3359
#                       ROCKVILLE              410
#                       OLNEY                  375
#                       KENSINGTON              88
#                       BROOKEVILLE             68
#                       SANDY SPRING            43
#                       ASHTON                  19
#                       SPENCERVILLE             6
#                       BRINKLOW                 5
#                       GAITHERSBURG             2
# Name: City, dtype: int64

# %% [markdown]
# Silverspring is the area where the most crimes occur. It correspond to the area with the cities **SILVER SPRING, BURTONSVILLE, TAKOMA PARK, SPENCERVILLE, CHEVY CHASE, LAUREL**

# %% [markdown]
# #### Crimes per Capita
#
# We used the [2015 crime annual report](https://www.montgomerycountymd.gov/POL/Resources/Files/crime/MCP2015AnnualCrimeReportFINAL.pdf) to get the population per district and used this values as the 2013 population per district. As 'Other' and 'Tahoma Park' is not directly related to one of the six districts, we will desconsider these Police Districts.

# %%
pop_per_dist = {'ROCKVILLE': 149118, 
                'BETHESDA': 182883,
                'SILVER SPRING': 152991,
                'WHEATON': 208283,
                'GERMANTOWN': 131391,
                'MONTGOMERY VILLAGE': 147486}
df_pop_per_dist = pd.Series(pop_per_dist)


crimes_per_dist = crimes_count[df_pop_per_dist.index.values.tolist()]
crimes_per_capita = crimes_per_dist.divide(df_pop_per_dist, level=0)

print(df_pop_per_dist)
print(crimes_per_dist)
print(crimes_per_capita.sort_values(ascending=False))
# Out:
# BETHESDA              182883
# GERMANTOWN            131391
# MONTGOMERY VILLAGE    147486
# ROCKVILLE             149118
# SILVER SPRING         152991
# WHEATON               208283
# dtype: int64
# Police District Name  Police District Number
# BETHESDA              2D                        3383
# GERMANTOWN            5D                        2755
# MONTGOMERY VILLAGE    6D                        3812
# ROCKVILLE             1D                        3480
# SILVER SPRING         3D                        5533
# WHEATON               4D                        4375
# Name: Police District Number, dtype: int64
# Police District Name  Police District Number
# SILVER SPRING         3D                        0.036166
# MONTGOMERY VILLAGE    6D                        0.025847
# ROCKVILLE             1D                        0.023337
# WHEATON               4D                        0.021005
# GERMANTOWN            5D                        0.020968
# BETHESDA              2D                        0.018498
# dtype: float64

# %% [markdown]
# Silverspring has the highest number of crimes per capita (0.036 crimes per capita) and Bethesda has the lowest number (0.018 crimes per capita).

# %% [markdown]
# # 5 Analyzing types of crime

# %% [markdown]
# To make a deeper analysis about the crime categories listed in the events, it is necessary to account crime categories in the dataset by aggregating categories in rows and accounting the frequencies for crime categories. We can first check the crime class variety:

# %%
crimes.groupby(['Class','Class Description'],as_index=False).sum()[['Class','Class Description']]
# Out:
#      Class                     Class Description
# 0      111                      HOMICIDE-FIREARM
# 1      115                        HOMICIDE-OTHER
# 2      211                            RAPE-FORCE
# 3      212                RAPE - ATTEMPT - FORCE
# 4      311                  ROB FIREARM - STREET
# 5      312              ROB FIREARM - COMMERCIAL
# 6      313             ROB FIREARM - GAS/SVC STA
# 7      314             ROB FIREARM - CONV. STORE
# 8      315             ROB FIREARM - RESIDENTIAL
# 9      316   ROB FIREARM - FINANCIAL INSTITUTION
# 10     317                   ROB FIREARM - OTHER
# 11     318                   ROB FIREARM CARJACK
# 12     321           ROB KNIFE/CUT INST - STREET
# 13     322             ROB KNIFE/CUT INST - COMM
# 14     324           ROB KNIFE/CUT - CONV. STORE
# 15     325      ROB KNIFE/CUT INST - RESIDENTIAL
# 16     327             ROB KNIFE/CUT INS - OTHER
# 17     328                 ROB KNIFE CUT CARJACK
# 18     331             ROB OTHER WEAPON - STREET
# 19     332               ROB OTHER WEAPON - COMM
# 20     333         ROB OTHER WEAPON GAS/SVC  STA
# 21     335                ROB OTHER WEAPON - RES
# 22     337              ROB OTHER WEAPON - OTHER
# 23     341                 ROB STNG ARM - STREET
# 24     342                   ROB STNG ARM - COMM
# 25     343             ROB STN ARM - GAS/SVC STA
# 26     344             ROB STN ARM - CONV. STORE
# 27     345                    ROB STNG ARM - RES
# 28     346  ROB STNG ARM - FINANCIAL INSTITUTION
# 29     347                  ROB STNG ARM - OTHER
# ..     ...                                   ...
# 255   2752   FUGITIVE FROM JUSTICE(OUT OF STATE)
# 256   2791   ALL OTHER NON-TRAFFIC CRIM OFFENSES
# 257   2811                        ABANDONED AUTO
# 258   2812           DRIVING UNDER THE INFLUENCE
# 259   2813                        TRAFFIC HAZARD
# 260   2814                      PARKING OFFENSES
# 261   2815      VIOLATION OF ALCOHOL RESTRICTION
# 262   2911            SUDDEN DEATH ACC NON TRAFF
# 263   2912                 SUDDEN DEATH DROWNING
# 264   2913                  SUDDEN DEATH NATURAL
# 265   2914             SUDDEN DEATH UNDETERMINED
# 266   2934                                 DRUNK
# 267   2935                            FIRE OTHER
# 268   2936                            ILL PERSON
# 269   2937                    INJURY- NONTRAFFIC
# 270   2938                       POL INFORMATION
# 271   2939               HOMELAND SECURITY EVENT
# 272   2941                         LOST PROPERTY
# 273   2942                      MENTAL TRANSPORT
# 274   2943                        MISSING PERSON
# 275   2945          RECOVERED PROPERTY - FIREARM
# 276   2946          RECOVERED PROPERTY/MONT. CO.
# 277   2947              RECOVERED PROPERTY/OTHER
# 278   2949          SANE COLLECTION NON-STRANGER
# 279   2951                        FAMILY TROUBLE
# 280   2952         SUSPICIOUS SIT/PERSON/VEHICLE
# 281   2991                   OTHER MISCELLANEOUS
# 282   3213              ANIMAL OFFENSE - HOT CAR
# 283   3220      ANIMAL OFFENSE - AGG ANIMAL/BITE
# 284   3240               ANIMAL NUISANCE/BARKING
#
# [285 rows x 2 columns]

# %% [markdown]
# The above table shows that there are **285** crimes classes in the dataset, alongside with their respective descriptions. A brief observation of these descriptions shows that not all occurrencies are directly or closely related to crimes. This makes us believe that the provided dataset does not list only crimes but rather police reports. Anyway, an interesting next step is to account the frequencies for each crime class:

# %%
print(crimes['Class Description'].value_counts().head(10))
# Out:
# DRIVING UNDER THE INFLUENCE        1710
# CDS-POSS MARIJUANA/HASHISH         1334
# POL INFORMATION                    1191
# LARCENY FROM AUTO OVER $200         914
# LARCENY FROM BUILDING OVER $200     895
# MENTAL TRANSPORT                    841
# VANDALISM-MOTOR VEHICLE             762
# LOST PROPERTY                       729
# LARCENY OTHER OVER $200             652
# LARCENY FROM AUTO UNDER $50         610
# Name: Class Description, dtype: int64

# %%
print(crimes['Class Description'].value_counts(normalize=True).head(10))
# Out:
# DRIVING UNDER THE INFLUENCE        0.073174
# CDS-POSS MARIJUANA/HASHISH         0.057084
# POL INFORMATION                    0.050965
# LARCENY FROM AUTO OVER $200        0.039112
# LARCENY FROM BUILDING OVER $200    0.038299
# MENTAL TRANSPORT                   0.035988
# VANDALISM-MOTOR VEHICLE            0.032607
# LOST PROPERTY                      0.031195
# LARCENY OTHER OVER $200            0.027900
# LARCENY FROM AUTO UNDER $50        0.026103
# Name: Class Description, dtype: float64

# %%
crimes['Class Description'].value_counts().head().plot(kind='bar')

# %%
print(crimes['Class Description'].value_counts().tail(10))
# Out:
# CDS-USE SYNTH DEMEROL/METADONE            1
# BURG FORCE-SCH/DAY                        1
# AGG  ASSLT BEAT/INJ P.O.                  1
# PARKING OFFENSES                          1
# ANIMAL NUISANCE/BARKING                   1
# VANDALISM POSSESSION GRAFFITI MATERIAL    1
# CDS-MANU DRUG OVERDOSE NOT FATAL          1
# EMBEZZLE UNDER $300                       1
# TRAFFIC HAZARD                            1
# BURG NO FORCE - SCH/TIME UNK              1
# Name: Class Description, dtype: int64

# %% [markdown]
# Thus, the most frequent police event in 2013 was **"DRIVING UNDER THE INFLUENCE"** (of alcohol or narcotic substances, probably) and events such as **"VANDALISM GRAFFITI CHURCH/TEMP"** are the least frequent (among much others).

# %% [markdown]
# The descriptions of crime classes are rich in words, thus, based in this words, we can make assumptions about the
# presence of violence in this crimes. To accomplish this, it is needed to take a look in to these descriptions and
# select some words related to violence to build a dictionary or seach pattern.

# %% [markdown]
# To do so, a good strategy is to build a word cloud from crime descriptions and select some violece-related words:

# %%
from collections import Counter
import string

#import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
stopw = set(stopwords.words('english'))

#from string import digits
text = crimes['Class Description'].to_string().lower()

text = ' '.join([word for word in text.split() if word not in stopw])

text = ''.join(i for i in text if not i.isdigit())
#text = ''.join(ch for ch in text if ch not in set(string.punctuation))
translator = str.maketrans(string.punctuation, ' '*len(string.punctuation)) #map punctuation to space
text = text.translate(translator)
text = text.split()

text_dict = Counter(text)

# WordCloud module: https://github.com/amueller/word_cloud
from wordcloud import WordCloud

text = crimes['Class Description'].to_string()
#wordcloud = WordCloud(background_color='white', height=1000, width=2500).generate(text)
wordcloud = WordCloud(background_color='white', height=1000, width=1000).generate_from_frequencies(text_dict)
plt.figure(1,[100,250])
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# This word cloud makes easy the selection of the targeted words. However, we have also to keep in mind that some
# words were abreviated.

# %%
violence_words = ['ASSAULT','ROB','WEAPON','FIGHT', 'RAPE', 'STAB', 'KNIFE','FIREARM'] # this list must be increased.
violence_pattern = '|'.join(violence_words)

# %% [markdown]
# Based on this search pattern containing words related to violence, we can search for these words in the descriptions and build a new boolen value column to indicate if the police event is somehow related to some kind of violence.

# %%
crimes['is_violent'] = crimes['Class Description'].str.contains(violence_pattern, case=False)

# %% [markdown]
# Finally, we list only the events with the flag **"is_violent"** set to true.

# %%
crimes[crimes['is_violent'] == True]
# Out:
#        Incident ID  CR Number    Dispatch Date / Time   datetime_Dispatch  \
# 13       200922213   13035028  07/26/2013 10:18:25 PM 2013-07-26 22:18:25
# 20       200925993   13030560  07/01/2013 03:11:18 AM 2013-07-01 03:11:18
# 84       200926085   13030655  07/01/2013 11:52:31 AM 2013-07-01 11:52:31
# 94       200926101   13030702  07/01/2013 06:16:56 PM 2013-07-01 18:16:56
# 107      200926123   13030729  07/01/2013 09:07:46 PM 2013-07-01 21:07:46
# 110      200926127   13030557  07/01/2013 01:46:47 AM 2013-07-01 01:46:47
# 113      200926131   13030748  07/02/2013 12:53:06 AM 2013-07-02 00:53:06
# 114      200926132   13030742  07/01/2013 11:08:12 PM 2013-07-01 23:08:12
# 190      200926227   13030869  07/02/2013 04:59:41 PM 2013-07-02 16:59:41
# 211      200926260   13030932  07/02/2013 11:55:06 PM 2013-07-02 23:55:06
# 213      200926262   13030929  07/02/2013 11:18:09 PM 2013-07-02 23:18:09
# 225      200926281   13030827  07/02/2013 01:54:12 PM 2013-07-02 13:54:12
# 275      200926343   13031018  07/03/2013 12:03:47 PM 2013-07-03 12:03:47
# 284      200926353   13031058  07/03/2013 04:08:28 PM 2013-07-03 16:08:28
# 291      200926363   13031062  07/03/2013 03:47:23 PM 2013-07-03 15:47:23
# 293      200926365   13030899  07/02/2013 08:09:54 PM 2013-07-02 20:09:54
# 299      200926371   13031099  07/03/2013 06:44:06 PM 2013-07-03 18:44:06
# 314      200926391   13031118  07/03/2013 08:13:18 PM 2013-07-03 20:13:18
# 321      200926401   13031128  07/03/2013 10:07:22 PM 2013-07-03 22:07:22
# 336      200926418   13030843  07/02/2013 03:04:53 PM 2013-07-02 15:04:53
# 366      200926455   13031228  07/04/2013 05:11:35 PM 2013-07-04 17:11:35
# 373      200926470   13031106  07/03/2013 07:00:02 PM 2013-07-03 19:00:02
# 376      200926475   13031124  07/03/2013 09:28:12 PM 2013-07-03 21:28:12
# 382      200926482   13031256  07/04/2013 09:37:50 PM 2013-07-04 21:37:50
# 385      200926485   13031147  07/04/2013 12:12:27 AM 2013-07-04 00:12:27
# 395      200926496   13031086  07/03/2013 05:45:36 PM 2013-07-03 17:45:36
# 396      200926497   13031285  07/05/2013 12:46:32 AM 2013-07-05 00:46:32
# 401      200926502   13031280  07/05/2013 12:04:54 AM 2013-07-05 00:04:54
# 457      200926572   13031109  07/03/2013 07:01:54 PM 2013-07-03 19:01:54
# 462      200926577   13031387  07/05/2013 03:34:25 PM 2013-07-05 15:34:25
# ...            ...        ...                     ...                 ...
# 22769    200951763   13062820  12/31/2013 12:54:29 AM 2013-12-31 00:54:29
# 22774    200951769   13062813  12/31/2013 12:29:00 AM 2013-12-31 00:29:00
# 22779    200951775   13062824  12/31/2013 02:07:07 AM 2013-12-31 02:07:07
# 22855    200951862   13062821  12/31/2013 01:33:30 AM 2013-12-31 01:33:30
# 22860    200951869   13062203  12/26/2013 07:00:00 PM 2013-12-26 19:00:00
# 22869    200951878   13062223  12/26/2013 08:32:15 PM 2013-12-26 20:32:15
# 22872    200951881   13062934  12/31/2013 05:03:33 PM 2013-12-31 17:03:33
# 22887    200951899   13062957  12/31/2013 08:50:15 PM 2013-12-31 20:50:15
# 22894    200951906   13062963  12/31/2013 07:51:32 PM 2013-12-31 19:51:32
# 22945    200952053   13053691  11/08/2013 08:14:24 AM 2013-11-08 08:14:24
# 22968    200952091   13060630  12/17/2013 06:08:35 PM 2013-12-17 18:08:35
# 23043    200952400   13062780  12/30/2013 07:20:33 PM 2013-12-30 19:20:33
# 23044    200952478   13062784  12/30/2013 08:25:30 PM 2013-12-30 20:25:30
# 23102    200952681   14000692  11/07/2013 03:37:23 PM 2013-11-07 15:37:23
# 23140    200952823   14001035  09/13/2013 09:03:07 PM 2013-09-13 21:03:07
# 23155    200952860   13058648  12/06/2013 05:10:11 AM 2013-12-06 05:10:11
# 23294    200953825   13062212  12/26/2013 07:52:33 PM 2013-12-26 19:52:33
# 23300    200954256   13055678  11/19/2013 01:15:54 PM 2013-11-19 13:15:54
# 23309    200954961   14003639  12/13/2013 05:25:55 PM 2013-12-13 17:25:55
# 23318    200955743   14002641  11/19/2013 09:58:15 PM 2013-11-19 21:58:15
# 23320    200955832   13061199  12/20/2013 10:00:59 AM 2013-12-20 10:00:59
# 23330    200957609   13046514  09/30/2013 10:34:09 AM 2013-09-30 10:34:09
# 23331    200957695   14006700  12/30/2013 08:13:26 PM 2013-12-30 20:13:26
# 23338    200960925   13040233  08/26/2013 10:54:57 AM 2013-08-26 10:54:57
# 23341    200961896   14011791  12/29/2013 10:25:48 PM 2013-12-29 22:25:48
# 23352    200971805   13051038  10/25/2013 12:16:28 PM 2013-10-25 12:16:28
# 23359    200991749   13058280  11/25/2013 08:39:07 AM 2013-11-25 08:39:07
# 23364    201067548   13061049  12/19/2013 05:06:19 PM 2013-12-19 17:06:19
# 23365    201070054   13061002  12/19/2013 02:32:35 PM 2013-12-19 14:32:35
# 23366    201070057   13053288  11/06/2013 10:38:26 AM 2013-11-06 10:38:26
#
#        Class                   Class Description Police District Name  \
# 13       821            SIMPLE ASSAULT - CITIZEN        SILVER SPRING
# 20       811         ASSAULT & BATTERY - CITIZEN        SILVER SPRING
# 84       341               ROB STNG ARM - STREET             BETHESDA
# 94       315           ROB FIREARM - RESIDENTIAL   MONTGOMERY VILLAGE
# 107      813    ASSAULT & BATTERY SPOUSE/PARTNER   MONTGOMERY VILLAGE
# 110      811         ASSAULT & BATTERY - CITIZEN              WHEATON
# 113      811         ASSAULT & BATTERY - CITIZEN        SILVER SPRING
# 114      811         ASSAULT & BATTERY - CITIZEN            ROCKVILLE
# 190      813    ASSAULT & BATTERY SPOUSE/PARTNER        SILVER SPRING
# 211      332             ROB OTHER WEAPON - COMM        SILVER SPRING
# 213      811         ASSAULT & BATTERY - CITIZEN   MONTGOMERY VILLAGE
# 225      811         ASSAULT & BATTERY - CITIZEN             BETHESDA
# 275      311                ROB FIREARM - STREET        SILVER SPRING
# 284     1521           WEAPON POSSESSION HANDGUN   MONTGOMERY VILLAGE
# 291      811         ASSAULT & BATTERY - CITIZEN            ROCKVILLE
# 293      811         ASSAULT & BATTERY - CITIZEN   MONTGOMERY VILLAGE
# 299      811         ASSAULT & BATTERY - CITIZEN   MONTGOMERY VILLAGE
# 314      311                ROB FIREARM - STREET        SILVER SPRING
# 321      821            SIMPLE ASSAULT - CITIZEN           GERMANTOWN
# 336      821            SIMPLE ASSAULT - CITIZEN             BETHESDA
# 366     1513       WEAPON CONCEALED OTHER WEAPON        SILVER SPRING
# 373      811         ASSAULT & BATTERY - CITIZEN        SILVER SPRING
# 376      824       SIMPLE ASSAULT OTHER DOMESTIC           GERMANTOWN
# 382      823       SIMPLE ASSAULT SPOUSE/PARTNER            ROCKVILLE
# 385      812  ASSAULT & BATTERY - POLICE OFFICER           GERMANTOWN
# 395      813    ASSAULT & BATTERY SPOUSE/PARTNER        SILVER SPRING
# 396      347                ROB STNG ARM - OTHER            ROCKVILLE
# 401      813    ASSAULT & BATTERY SPOUSE/PARTNER             BETHESDA
# 457      822                 SIMPLE ASSAULT - PO        SILVER SPRING
# 462      814    ASSAULT & BATTERY OTHER DOMESTIC            ROCKVILLE
# ...      ...                                 ...                  ...
# 22769    824       SIMPLE ASSAULT OTHER DOMESTIC   MONTGOMERY VILLAGE
# 22774    823       SIMPLE ASSAULT SPOUSE/PARTNER        SILVER SPRING
# 22779   1513       WEAPON CONCEALED OTHER WEAPON            ROCKVILLE
# 22855    822                 SIMPLE ASSAULT - PO           GERMANTOWN
# 22860    821            SIMPLE ASSAULT - CITIZEN            ROCKVILLE
# 22869    823       SIMPLE ASSAULT SPOUSE/PARTNER              WHEATON
# 22872    347                ROB STNG ARM - OTHER             BETHESDA
# 22887    813    ASSAULT & BATTERY SPOUSE/PARTNER              WHEATON
# 22894    812  ASSAULT & BATTERY - POLICE OFFICER           GERMANTOWN
# 22945   1711          SEX OFFENSE - SEX  ASSAULT        SILVER SPRING
# 22968   1711          SEX OFFENSE - SEX  ASSAULT             BETHESDA
# 23043    811         ASSAULT & BATTERY - CITIZEN             BETHESDA
# 23044    341               ROB STNG ARM - STREET              WHEATON
# 23102    824       SIMPLE ASSAULT OTHER DOMESTIC        SILVER SPRING
# 23140    813    ASSAULT & BATTERY SPOUSE/PARTNER              WHEATON
# 23155   1521           WEAPON POSSESSION HANDGUN        SILVER SPRING
# 23294    824       SIMPLE ASSAULT OTHER DOMESTIC   MONTGOMERY VILLAGE
# 23300   2945        RECOVERED PROPERTY - FIREARM              WHEATON
# 23309    814    ASSAULT & BATTERY OTHER DOMESTIC        SILVER SPRING
# 23318    824       SIMPLE ASSAULT OTHER DOMESTIC   MONTGOMERY VILLAGE
# 23320   1711          SEX OFFENSE - SEX  ASSAULT        SILVER SPRING
# 23330   1711          SEX OFFENSE - SEX  ASSAULT            ROCKVILLE
# 23331    813    ASSAULT & BATTERY SPOUSE/PARTNER        SILVER SPRING
# 23338    815         ASSAULT & BATTERY - ELDERLY   MONTGOMERY VILLAGE
# 23341    821            SIMPLE ASSAULT - CITIZEN        SILVER SPRING
# 23352    342                 ROB STNG ARM - COMM   MONTGOMERY VILLAGE
# 23359    813    ASSAULT & BATTERY SPOUSE/PARTNER             BETHESDA
# 23364   1711          SEX OFFENSE - SEX  ASSAULT              WHEATON
# 23365   1711          SEX OFFENSE - SEX  ASSAULT              WHEATON
# 23366   1711          SEX OFFENSE - SEX  ASSAULT              WHEATON
#
#                     Block Address                City State    ...      \
# 13             2100 E RANDOLPH RD       SILVER SPRING    MD    ...
# 20              8200  GEORGIA AVE       SILVER SPRING    MD    ...
# 84            4800  MONTGOMERY LN            BETHESDA    MD    ...
# 94          18400  LOST KNIFE CIR  MONTGOMERY VILLAGE    MD    ...
# 107             9700  BRASSIE WAY  MONTGOMERY VILLAGE    MD    ...
# 110       2700  UNIVERSITY BLVD W       SILVER SPRING    MD    ...
# 113             900  ELLSWORTH DR       SILVER SPRING    MD    ...
# 114             300  PRETTYMAN DR           ROCKVILLE    MD    ...
# 190      10200  NEW HAMPSHIRE AVE       SILVER SPRING    MD    ...
# 211             7900  GEORGIA AVE       SILVER SPRING    MD    ...
# 213      9800  WASHINGTONIAN BLVD        GAITHERSBURG    MD    ...
# 225              11200  EMPIRE LN           ROCKVILLE    MD    ...
# 275      13800  OLD COLUMBIA PIKE       SILVER SPRING    MD    ...
# 284          1  W WATKINS MILL RD        GAITHERSBURG    MD    ...
# 291             600  LOFSTRAND LN           ROCKVILLE    MD    ...
# 293              1  W DIAMOND AVE        GAITHERSBURG    MD    ...
# 299               1   RUSSELL AVE        GAITHERSBURG    MD    ...
# 314            1100  CHICKASAW DR       SILVER SPRING    MD    ...
# 321             11200  SIBLEY TER          GERMANTOWN    MD    ...
# 336          10400  MOTOR CITY DR            BETHESDA    MD    ...
# 366                11400  JULY DR       SILVER SPRING    MD    ...
# 373              1000  QUEBEC TER       SILVER SPRING    MD    ...
# 376         23400  TAILOR SHOP PL          CLARKSBURG    MD    ...
# 382         13000  TWINBROOK PKWY           ROCKVILLE    MD    ...
# 385           19900  CENTURY BLVD          GERMANTOWN    MD    ...
# 395             8800  GARLAND AVE       SILVER SPRING    MD    ...
# 396    14300  STONEBRIDGE VIEW DR        GAITHERSBURG    MD    ...
# 401            11300  WOODGLEN DR           ROCKVILLE    MD    ...
# 457           8500  COLESVILLE RD       SILVER SPRING    MD    ...
# 462         11300  SEVEN LOCKS RD             POTOMAC    MD    ...
# ...                           ...                 ...   ...    ...
# 22769      19100  MILLS CHOICE RD  MONTGOMERY VILLAGE    MD    ...
# 22774       8600  PINEY BRANCH RD       SILVER SPRING    MD    ...
# 22779       900 N STONESTREET AVE           ROCKVILLE    MD    ...
# 22855          12700  WISTERIA DR          GERMANTOWN    MD    ...
# 22860        1300  SEVEN LOCKS RD             POTOMAC    MD    ...
# 22869       2900  CLOVERCREST WAY               OLNEY    MD    ...
# 22872    10400  OLD GEORGETOWN RD            BETHESDA    MD    ...
# 22887              3800  ADAMS DR       SILVER SPRING    MD    ...
# 22894        11400  BRUNDIDGE TER          GERMANTOWN    MD    ...
# 22945       8600  PINEY BRANCH RD       SILVER SPRING    MD    ...
# 22968     10500  METROPOLITAN AVE          KENSINGTON    MD    ...
# 23043          4900  BETHESDA AVE            BETHESDA    MD    ...
# 23044           2300  PRICHARD RD       SILVER SPRING    MD    ...
# 23102    10100  NEW HAMPSHIRE AVE       SILVER SPRING    MD    ...
# 23140          1   SILVER MOON DR       SILVER SPRING    MD    ...
# 23155           11500  STEWART LN       SILVER SPRING    MD    ...
# 23294       18400  LOST KNIFE CIR  MONTGOMERY VILLAGE    MD    ...
# 23300          14200  DRAYTON AVE       SILVER SPRING    MD    ...
# 23309             1000  WAYNE AVE       SILVER SPRING    MD    ...
# 23318       10000  FOREST VIEW PL  MONTGOMERY VILLAGE    MD    ...
# 23320          13800  CASTLE BLVD       SILVER SPRING    MD    ...
# 23330   12000  CHASE CROSSING CIR           ROCKVILLE    MD    ...
# 23331               8400  16TH ST       SILVER SPRING    MD    ...
# 23338       10000  FOREST VIEW PL  MONTGOMERY VILLAGE    MD    ...
# 23341            1700  JANUARY DR       SILVER SPRING    MD    ...
# 23352        200  PROFESSIONAL DR        GAITHERSBURG    MD    ...
# 23359              9400  RIVER RD             POTOMAC    MD    ...
# 23364            10500  LESTER ST       SILVER SPRING    MD    ...
# 23365            10500  LESTER ST       SILVER SPRING    MD    ...
# 23366          10500  TENBROOK DR       SILVER SPRING    MD    ...
#
#              datetime_End   Latitude  Longitude Police District Number  \
# 13    2013-05-28 20:00:00  39.064334 -76.968985                     3D
# 20                    NaT  38.991646 -77.026611                     3D
# 84                    NaT  38.983476 -77.095031                     2D
# 94    2013-06-30 21:00:00  39.158535 -77.198507                     6D
# 107   2013-06-28 11:00:00  39.175277 -77.202006                     6D
# 110                   NaT  39.040003 -77.055465                     4D
# 113   2013-07-02 01:00:00  38.996855 -77.025432                     3D
# 114                   NaT  39.094253 -77.193956                     1D
# 190   2013-07-02 16:59:00  39.022323 -76.977492                     3D
# 211   2013-07-02 23:18:00  38.985340 -77.026643                     3D
# 213                   NaT  39.114194 -77.197117                     6D
# 225   2013-07-02 13:40:00  39.040637 -77.119445                     2D
# 275   2013-07-03 12:03:00  39.081937 -76.953556                     3D
# 284                   NaT  39.147668 -77.232925                     6D
# 291                   NaT  39.093952 -77.141126                     1D
# 293                   NaT  39.141303 -77.199026                     6D
# 299                   NaT  39.141910 -77.196435                     6D
# 314                   NaT  38.996967 -76.990435                     3D
# 321   2013-07-03 22:15:00  39.177515 -77.233480                     5D
# 336   2013-07-02 15:40:00  39.026534 -77.143987                     2D
# 366                   NaT  39.041552 -76.981740                     3D
# 373   2013-07-03 17:00:00  38.999094 -76.989366                     3D
# 376                   NaT  39.243460 -77.282266                     5D
# 382   2013-07-04 21:30:00  39.069626 -77.114029                     1D
# 385                   NaT  39.182985 -77.263591                     5D
# 395                   NaT  39.000732 -77.000455                     3D
# 396                   NaT  39.089220 -77.214128                     1D
# 401                   NaT  39.041818 -77.113276                     2D
# 457                   NaT  38.995439 -77.029163                     3D
# 462                   NaT  39.040723 -77.159059                     1D
# ...                   ...        ...        ...                    ...
# 22769 2013-12-30 09:30:00  39.169145 -77.208021                     6D
# 22774                 NaT  38.998437 -77.000984                     3D
# 22779 2013-12-31 02:05:00  39.096015 -77.151240                     1D
# 22855                 NaT  39.171138 -77.262857                     5D
# 22860                 NaT  39.067069 -77.161752                     1D
# 22869                 NaT  39.159864 -77.058769                     4D
# 22872                 NaT  39.024895 -77.125321                     2D
# 22887                 NaT  39.045843 -77.074927                     4D
# 22894                 NaT  39.187516 -77.236745                     5D
# 22945 2011-07-30 00:00:00  38.998437 -77.000984                     3D
# 22968 2013-12-17 18:08:00  39.027146 -77.071191                     2D
# 23043 2013-12-30 19:13:00  38.980850 -77.098490                     2D
# 23044                 NaT  39.036473 -77.048741                     4D
# 23102 2013-11-07 15:50:00  39.020421 -76.976681                     3D
# 23140                 NaT  39.078155 -77.003942                     4D
# 23155                 NaT  39.045501 -76.983217                     3D
# 23294 2013-12-26 19:45:00  39.158535 -77.198507                     6D
# 23300                 NaT  39.090829 -76.998243                     4D
# 23309 2013-12-13 17:47:00  38.994547 -77.026889                     3D
# 23318 2013-11-19 22:27:00  39.189696 -77.203638                     6D
# 23320 2013-10-21 00:00:00  39.082004 -76.944630                     3D
# 23330 2012-12-07 00:00:00  39.054601 -77.120175                     1D
# 23331                 NaT  38.994585 -77.036323                     3D
# 23338                 NaT  39.189696 -77.203638                     6D
# 23341 2013-12-29 22:25:00  39.047113 -76.976409                     3D
# 23352                 NaT  39.162783 -77.227798                     6D
# 23359                 NaT  39.006676 -77.191161                     2D
# 23364                 NaT  39.029567 -77.032183                     4D
# 23365                 NaT  39.029567 -77.032183                     4D
# 23366                 NaT  39.027538 -77.027854                     4D
#
#                                         Location  Address Number  \
# 13      (39.064334220776551, -76.96898520383327)          2100.0
# 20     (38.991645598561853, -77.026611407863527)          8200.0
# 84      (38.98347594056618, -77.095030772565565)          4800.0
# 94     (39.158535187517721, -77.198507099162867)         18400.0
# 107    (39.175277218793383, -77.202005920168531)          9700.0
# 110      (39.04000342569455, -77.05546537991161)          2700.0
# 113    (38.996854942654743, -77.025432458803962)           900.0
# 114    (39.094252628626087, -77.193956080337713)           300.0
# 190    (39.022322832476917, -76.977491994186551)         10200.0
# 211    (38.985339578334042, -77.026643299608324)          7900.0
# 213     (39.114193821475745, -77.19711721320779)          9800.0
# 225    (39.040636815481399, -77.119444877958955)         11200.0
# 275     (39.08193744592932, -76.953555730624345)         13800.0
# 284     (39.14766829443758, -77.232924930021838)             1.0
# 291    (39.093952134450312, -77.141125866798845)           600.0
# 293    (39.141303089817868, -77.199026029164585)             1.0
# 299    (39.141910343844287, -77.196435356962624)             1.0
# 314    (38.996966625689296, -76.990435349859027)          1100.0
# 321    (39.177514571270628, -77.233479697127109)         11200.0
# 336    (39.026534378348721, -77.143986653791842)         10400.0
# 366    (39.041552472712311, -76.981739650097751)         11400.0
# 373    (38.999094336883722, -76.989365857685669)          1000.0
# 376    (39.243459503799969, -77.282265674102462)         23400.0
# 382    (39.069625902878428, -77.114028642194313)         13000.0
# 385    (39.182984514479564, -77.263590517285564)         19900.0
# 395    (39.000732443555144, -77.000454647490912)          8800.0
# 396    (39.089220250856201, -77.214127813793326)         14300.0
# 401     (39.041817597568645, -77.11327617285238)         11300.0
# 457    (38.995438738504539, -77.029162750717916)          8500.0
# 462    (39.040722723698899, -77.159059031867798)         11300.0
# ...                                          ...             ...
# 22769  (39.169145164841979, -77.208021016716998)         19100.0
# 22774  (38.998437104698858, -77.000983862981855)          8600.0
# 22779  (39.096014920597646, -77.151239791576785)           900.0
# 22855  (39.171138378117732, -77.262857483396218)         12700.0
# 22860  (39.067069051887877, -77.161752023924222)          1300.0
# 22869  (39.159863882131766, -77.058768747458103)          2900.0
# 22872  (39.024894757131648, -77.125321413900451)         10400.0
# 22887  (39.045843195594465, -77.074927471982264)          3800.0
# 22894  (39.187516136671022, -77.236745402711449)         11400.0
# 22945  (38.998437104698858, -77.000983862981855)          8600.0
# 22968  (39.027145771391574, -77.071191067276146)         10500.0
# 23043   (38.980850157786833, -77.09848983439997)          4900.0
# 23044  (39.036473346379395, -77.048741041723844)          2300.0
# 23102  (39.020421298181603, -76.976681402268269)         10100.0
# 23140  (39.078154598950832, -77.003942022352888)             1.0
# 23155  (39.045501477956108, -76.983216973691725)         11500.0
# 23294  (39.158535187517721, -77.198507099162867)         18400.0
# 23300  (39.090828685272925, -76.998243417544103)         14200.0
# 23309   (38.994547004172652, -77.02688940655807)          1000.0
# 23318   (39.18969632066694, -77.203637911358129)         10000.0
# 23320  (39.082003600509331, -76.944629788439116)         13800.0
# 23330  (39.054601417876142, -77.120175373881679)         12000.0
# 23331  (38.994585078675286, -77.036323447389023)          8400.0
# 23338   (39.18969632066694, -77.203637911358129)         10000.0
# 23341  (39.047113080368867, -76.976409428571344)          1700.0
# 23352  (39.162783208362498, -77.227797541783431)           200.0
# 23359   (39.00667556544505, -77.191161277303507)          9400.0
# 23364  (39.029566677305858, -77.032182692678049)         10500.0
# 23365  (39.029566677305858, -77.032182692678049)         10500.0
# 23366  (39.027537885621783, -77.027853776247923)         10500.0
#
#       number_of_crimes datetime_Dispatch_date datetime_Start_date is_violent
# 13                   1             2013-07-26          2013-05-27       True
# 20                   1             2013-07-01          2013-07-01       True
# 84                   1             2013-07-01          2013-07-01       True
# 94                   1             2013-07-01          2013-06-30       True
# 107                  1             2013-07-01          2013-06-28       True
# 110                  1             2013-07-01          2013-07-01       True
# 113                  1             2013-07-02          2013-07-02       True
# 114                  1             2013-07-01          2013-06-28       True
# 190                  1             2013-07-02          2013-07-02       True
# 211                  1             2013-07-02          2013-07-02       True
# 213                  1             2013-07-02          2013-07-02       True
# 225                  1             2013-07-02          2013-07-02       True
# 275                  1             2013-07-03          2013-07-03       True
# 284                  1             2013-07-03          2013-07-03       True
# 291                  1             2013-07-03          2013-07-03       True
# 293                  1             2013-07-02          2013-07-02       True
# 299                  1             2013-07-03          2013-07-03       True
# 314                  1             2013-07-03          2013-07-03       True
# 321                  1             2013-07-03          2013-07-03       True
# 336                  1             2013-07-02          2013-07-02       True
# 366                  1             2013-07-04          2013-07-04       True
# 373                  1             2013-07-03          2013-07-03       True
# 376                  1             2013-07-03          2013-07-03       True
# 382                  1             2013-07-04          2013-07-04       True
# 385                  1             2013-07-04          2013-07-04       True
# 395                  1             2013-07-03          2013-07-03       True
# 396                  1             2013-07-05          2013-07-05       True
# 401                  1             2013-07-05          2013-07-05       True
# 457                  1             2013-07-03          2013-07-03       True
# 462                  1             2013-07-05          2013-07-05       True
# ...                ...                    ...                 ...        ...
# 22769                1             2013-12-31          2013-12-30       True
# 22774                1             2013-12-31          2013-12-31       True
# 22779                1             2013-12-31          2013-12-31       True
# 22855                1             2013-12-31          2013-12-31       True
# 22860                1             2013-12-26          2013-12-26       True
# 22869                1             2013-12-26          2013-12-26       True
# 22872                1             2013-12-31          2013-12-31       True
# 22887                1             2013-12-31          2013-12-31       True
# 22894                1             2013-12-31          2013-12-31       True
# 22945                1             2013-11-08          2011-01-01       True
# 22968                1             2013-12-17          2012-10-01       True
# 23043                1             2013-12-30          2013-12-30       True
# 23044                1             2013-12-30          2013-12-30       True
# 23102                1             2013-11-07          2013-11-07       True
# 23140                1             2013-09-13          2013-09-13       True
# 23155                1             2013-12-06          2013-12-06       True
# 23294                1             2013-12-26          2013-12-26       True
# 23300                1             2013-11-19          2013-11-19       True
# 23309                1             2013-12-13          2013-12-13       True
# 23318                1             2013-11-19          2013-11-19       True
# 23320                1             2013-12-20          2010-01-01       True
# 23330                1             2013-09-30          2009-07-06       True
# 23331                1             2013-12-30          2013-12-30       True
# 23338                1             2013-08-26          2013-08-26       True
# 23341                1             2013-12-29          2013-12-29       True
# 23352                1             2013-10-25          2013-08-11       True
# 23359                1             2013-11-25          2013-11-25       True
# 23364                1             2013-12-19          2013-12-19       True
# 23365                1             2013-12-19          2013-12-19       True
# 23366                1             2013-11-06          2013-11-06       True
#
# [2110 rows x 29 columns]

# %% [markdown]
# # 6 Combine Analysis

# %% [markdown]
# We are able now to combine our time and location analysis to answer more complex questions. We can determine were and when the majority of crimes are violent. It is important first get knowing the myriad of locations present in this dataset of Montgomery County:

# %%
crimes.groupby(['Block Address','City','Police District Name'],as_index=False).sum()[['Block Address','City','Police District Name']]
# Out:
#                 Block Address                City Police District Name
# 0     1   270_370-SAM EIG RMP        GAITHERSBURG   MONTGOMERY VILLAGE
# 1            1   ALDERLEAF CT          GERMANTOWN           GERMANTOWN
# 2          1   ALPEN GREEN CT        BURTONSVILLE        SILVER SPRING
# 3              1   ANAMOSA CT             DERWOOD            ROCKVILLE
# 4                 1   ANNA CT        GAITHERSBURG   MONTGOMERY VILLAGE
# 5                 1   APEX CT        GAITHERSBURG   MONTGOMERY VILLAGE
# 6          1   APPLE GROVE RD       SILVER SPRING        SILVER SPRING
# 7           1   APPLE SEED LN        GAITHERSBURG   MONTGOMERY VILLAGE
# 8           1   APPLEGRATH CT          GERMANTOWN           GERMANTOWN
# 9              1   APRICOT CT        GAITHERSBURG            ROCKVILLE
# 10              1   ASHTON RD              ASHTON              WHEATON
# 11        1   AUTUMN HILL WAY        GAITHERSBURG   MONTGOMERY VILLAGE
# 12             1   BAILEYS CT       SILVER SPRING              WHEATON
# 13           1   BALLINGER CT        BURTONSVILLE        SILVER SPRING
# 14           1   BALTIMORE RD           ROCKVILLE            ROCKVILLE
# 15           1   BANNISTER CT        GAITHERSBURG   MONTGOMERY VILLAGE
# 16             1   BARKLEY LN        GAITHERSBURG   MONTGOMERY VILLAGE
# 17         1   BARRINGTON FAR           ROCKVILLE            ROCKVILLE
# 18           1   BASILDON CIR           ROCKVILLE            ROCKVILLE
# 19        1   BEACON HILL WAY        GAITHERSBURG   MONTGOMERY VILLAGE
# 20              1   BEALL AVE           ROCKVILLE            ROCKVILLE
# 21        1   BELLE HOLLOW CT        GAITHERSBURG           GERMANTOWN
# 22         1   BEMAN WOODS CT             POTOMAC             BETHESDA
# 23               1   BENJI CT        GAITHERSBURG   MONTGOMERY VILLAGE
# 24            1   BENTANA WAY           ROCKVILLE            ROCKVILLE
# 25     1   BETHESDA METRO CTR            BETHESDA             BETHESDA
# 26            1   BIG ACRE SQ        GAITHERSBURG   MONTGOMERY VILLAGE
# 27        1   BLACK KETTLE CT               BOYDS           GERMANTOWN
# 28         1   BLUE HOSTA WAY           ROCKVILLE            ROCKVILLE
# 29         1   BLUE RIBBON CT        GAITHERSBURG   MONTGOMERY VILLAGE
# ...                       ...                 ...                  ...
# 8205             RANDOLPH  RD       SILVER SPRING              WHEATON
# 8206        ROYAL BONNET  CIR  MONTGOMERY VILLAGE   MONTGOMERY VILLAGE
# 8207             SAM EIG  HWY        GAITHERSBURG   MONTGOMERY VILLAGE
# 8208             SAM EIG  HWY           ROCKVILLE   MONTGOMERY VILLAGE
# 8209              SCENERY  DR          GERMANTOWN           GERMANTOWN
# 8210          SHADY GROVE  RD           ROCKVILLE            ROCKVILLE
# 8211         SHAKESPEARE  BLV          GERMANTOWN           GERMANTOWN
# 8212            SOMERSET  TER         CHEVY CHASE             BETHESDA
# 8213         SPENCERVILLE  RD        SPENCERVILLE              WHEATON
# 8214            STARDRIFT  DR          GERMANTOWN           GERMANTOWN
# 8215        SWALLOW POINT  RD  MONTGOMERY VILLAGE   MONTGOMERY VILLAGE
# 8216         TANYARD HILL  RD  MONTGOMERY VILLAGE   MONTGOMERY VILLAGE
# 8217           TEAGARDEN  CIR       SILVER SPRING        SILVER SPRING
# 8218       TINDAL SPRINGS  DR  MONTGOMERY VILLAGE   MONTGOMERY VILLAGE
# 8219          TOWER OAKS  BLV           ROCKVILLE            ROCKVILLE
# 8220              TRAVIS  AVE        GAITHERSBURG   MONTGOMERY VILLAGE
# 8221             TRIANGLE  LA       SILVER SPRING              WHEATON
# 8222          TWELVE OAKS  DR          GERMANTOWN   MONTGOMERY VILLAGE
# 8223               TYGART  LA  MONTGOMERY VILLAGE   MONTGOMERY VILLAGE
# 8224         UNIVERSITY E BLV       SILVER SPRING        SILVER SPRING
# 8225           VEIRS MILL  RD       SILVER SPRING              WHEATON
# 8226       VILLAGE CENTER  DR        SANDY SPRING              WHEATON
# 8227        W MONTGOMERY  AVE           ROCKVILLE            ROCKVILLE
# 8228       WALKERS CHOICE  RD  MONTGOMERY VILLAGE   MONTGOMERY VILLAGE
# 8229     WATERFORD HILLS  BLV          GERMANTOWN           GERMANTOWN
# 8230         WILLOW CREEK  DR    WASHINGTON GROVE   MONTGOMERY VILLAGE
# 8231           WISCONSIN  AVE         CHEVY CHASE             BETHESDA
# 8232            WOODFIELD  RD    WASHINGTON GROVE   MONTGOMERY VILLAGE
# 8233            WOODMONT  AVE            BETHESDA             BETHESDA
# 8234             WOOTTON  PKW           ROCKVILLE            ROCKVILLE
#
# [8235 rows x 3 columns]

# %% [markdown]
# So, there are 8,235 different locations (block addresses). It is possible to check the locations where violent crimes were more likely to occur:

# %% [markdown]
# #### Violent crimes

# %%
crimes[crimes.is_violent == True]['Block Address'].value_counts()
# Out:
# 700  RUSSELL AVE             12
# 11100  VEIRS MILL RD         11
# 2700  UNIVERSITY BLVD W      10
# 8800  PINEY BRANCH RD        10
# 22500  WIMS RD               10
# 13500  GEORGIA AVE            9
# 8600  PINEY BRANCH RD         9
# 900  ELLSWORTH DR             9
# 13800  CASTLE BLVD            9
# 13900  CASTLE BLVD            9
# 11200  OAK LEAF DR            8
# 7100  DEMOCRACY BLVD          8
# 400 N FREDERICK AVE           7
# 100  EDISON PARK DR           7
# 11600  LOCKWOOD DR            7
# 2500  ENNALLS AVE             7
# 300 N SUMMIT AVE              7
# 12300  GEORGIA AVE            7
# 7900  GEORGIA AVE             7
# 700  CLOPPER RD               7
# 1000  QUEBEC TER              7
# 1  W WATKINS MILL RD          7
# 18300  LOST KNIFE CIR         7
# 14100  OLD COLUMBIA PIKE      6
# 19700  CRYSTAL ROCK DR        6
# 200  PROFESSIONAL DR          6
# 18400  LOST KNIFE CIR         6
# 8500  COLESVILLE RD           6
# 11200  GRANDVIEW AVE          6
# 8400  COLESVILLE RD           6
#                              ..
# 5500  NICHOLSON LN            1
# 3700  INTERNATIONAL DR        1
# 3900  GREENCASTLE RD          1
# 1   SILVER MOON DR            1
# 800  LOXFORD TER              1
# 13400  DAVENTRY WAY           1
# 700  LONGWOOD DR              1
# 1900  AGATE DR                1
# 9700  VEIRS DR                1
# 2800  SCHUBERT DR             1
# 18800  WALKERS CHOICE RD      1
# 11700  OLD COLUMBIA PIKE      1
# 11100  LOCKWOOD DR            1
# 4100  PEPPERTREE LN           1
# 700  MC NEILL RD              1
# 4700  DORSET AVE              1
# 8600  11TH AVE                1
# 2600  BLUERIDGE AVE           1
# 1  E DEER PARK DR             1
# 3000  PIANO LN                1
# 23500  ROLLING FORK WAY       1
# 7000  LEMAY RD                1
# 1   METZ CT                   1
# 700  BRENT RD                 1
# 500  RAVEN AVE                1
# 1000  ROCKVILLE PIKE          1
# 3600  VAN HORN WAY            1
# 13500  KILDARE HILLS TER      1
# 100 W MONTGOMERY AVE          1
# 20400  FATHER HURLEY BLVD     1
# Name: Block Address, dtype: int64

# %% [markdown]
# Thus, the **"700  RUSSELL AVE"** is the block with the highest number of violent events.

# %%
crimes2 = crimes[crimes.is_violent == True]['Block Address'].value_counts() >= 2
crimes2.value_counts()
# Out:
# False    1008
# True      360
# Name: Block Address, dtype: int64

# %% [markdown]
# And **360** blocks experienced at least **2** violent events.

# %% [markdown]
# Similarly, we can figure out which cities in Montgomery County are more violent:

# %%
crimes[crimes.is_violent == True]['City'].value_counts()
# Out:
# SILVER SPRING         892
# GAITHERSBURG          309
# ROCKVILLE             285
# GERMANTOWN            201
# BETHESDA               99
# MONTGOMERY VILLAGE     77
# POTOMAC                36
# KENSINGTON             35
# BURTONSVILLE           29
# CLARKSBURG             25
# CHEVY CHASE            24
# OLNEY                  22
# DAMASCUS               21
# TAKOMA PARK            20
# DERWOOD                12
# POOLESVILLE             6
# BROOKEVILLE             5
# BOYDS                   5
# SANDY SPRING            3
# DICKERSON               2
# ASHTON                  2
# Name: City, dtype: int64

# %%
crimes[crimes.is_violent == True]['City'].value_counts().plot(kind='bar')

# %% [markdown]
# **"SILVER SPRING"** seems to be undeniably the most violent City in the Montgomery County.

# %% [markdown]
# We now check the day of the week and the part of day violent crimes mostly occurred.

# %%
crimes_window[crimes.is_violent == True]['datetime_Start'].dt.weekday_name.value_counts()
# Out:
# Saturday     334
# Sunday       314
# Wednesday    308
# Friday       296
# Tuesday      291
# Thursday     274
# Monday       255
# Name: datetime_Start, dtype: int64

# %%
crimes_window[crimes.is_violent == True]['datetime_Start'].dt.weekday_name.value_counts().plot(kind='bar')

# %%
crimes_window[crimes.is_violent == True].crimes_period.value_counts()
# Out:
# evening      742
# afternoon    557
# dawn         475
# morning      298
# Name: crimes_period, dtype: int64

# %%
crimes_window[crimes.is_violent == True].crimes_period.value_counts().plot()

# %% [markdown]
# Thus, the day of week where most violent events ocurred was **Saturday** and the part of the day in which the majority of the crimes take place is the **evening**.

# %% [markdown]
# #### Non-violent crimes

# %%
crimes[crimes.is_violent == False]['Block Address'].value_counts()
# Out:
# 11100  VEIRS MILL RD        280
# 700  RUSSELL AVE            203
# 100  EDISON PARK DR         171
# 7100  DEMOCRACY BLVD        146
# 12000  CHERRY HILL RD       137
# 20900  FREDERICK RD         133
# 11200  NEW HAMPSHIRE AVE    101
# 8600  COLESVILLE RD          78
# 900  ELLSWORTH DR            71
# 7300  CALHOUN PL             65
# 800  SLIGO AVE               59
# 11300  ROCKVILLE PIKE        51
# 11200  GRANDVIEW AVE         50
# 14000  CONNECTICUT AVE       48
# 8100  FENTON ST              48
# 8400  COLESVILLE RD          47
# 19500  FREDERICK RD          47
# 12300  GEORGIA AVE           47
# 20000  AIRCRAFT DR           46
# 11100  GEORGIA AVE           46
# 12000  ROCKVILLE PIKE        44
# 13800  OUTLET DR             44
# 1   MARYLAND AVE             42
# 1200  EAST WEST HWY          42
# 7900  GEORGIA AVE            40
# 14100  CASTLE BLVD           40
# 8500  FENTON ST              39
# 2500  ENNALLS AVE            39
# 400 N FREDERICK AVE          38
# 2300  RANDOLPH RD            37
#                            ...
# 1100  CADDINGTON AVE          1
# 18700  CINNAMON DR            1
# 19400  THOMAS FARM RD         1
# 1   OLDHAM RD                 1
# 8700  READING RD              1
# 7200  MAPLE AVE               1
# 15300  MANOR VILLAGE LN       1
# 10300  SUMMIT AVE             1
# 10500  GEORGIA AVE            1
# 17400  CHISWELL RD            1
# 1000  1ST ST                  1
# 1   BLUE RIBBON CT            1
# 400  ELMCROFT BLVD            1
# MARATHON  CIR                 1
# 2800  BLUERIDGE AVE           1
# 8300  BOUNDARY ST             1
# 10700  TENBROOK DR            1
# 7800  GARLAND AVE             1
# 1  S WASHINGTON ST            1
# 14900  DUFIEF MILL RD         1
# 3500  FLORAL ST               1
# 15200  MC KNEW RD             1
# 2800  BEECHMONT LN            1
# 10200  NORTON RD              1
# 1   MANORVALE CT              1
# 11400  MIDDLEBROOK RD         1
# 11700  TRAILRIDGE DR          1
# 13500  COLEFAIR DR            1
# 11300  KENTON PL              1
# 24000  WOODFIELD RD           1
# Name: Block Address, dtype: int64

# %% [markdown]
# The **"11100  VEIRS MILL RD "** is the block with the highest number of non-violent events and 700  RUSSELL AVE that is the block address with more violent crimes is the second in non-violent crimes ranking.

# %%
crimesN2 = crimes[crimes.is_violent == False]['Block Address'].value_counts() >= 2
crimesN2.value_counts()
# Out:
# False    4612
# True     3185
# Name: Block Address, dtype: int64

# %% [markdown]
# And 3185 blocks experienced at least 2 violent events.

# %% [markdown]
# Similarly, we can figure out which cities in Montgomery County has more non-violent crimes:

# %%
crimes[crimes.is_violent == False]['City'].value_counts()
# Out:
# SILVER SPRING         7734
# ROCKVILLE             3168
# GAITHERSBURG          3094
# GERMANTOWN            1969
# BETHESDA              1637
# MONTGOMERY VILLAGE     610
# POTOMAC                491
# CHEVY CHASE            474
# OLNEY                  358
# KENSINGTON             328
# BURTONSVILLE           275
# DERWOOD                258
# DAMASCUS               209
# CLARKSBURG             148
# TAKOMA PARK            121
# POOLESVILLE             99
# BOYDS                   85
# BROOKEVILLE             65
# SANDY SPRING            40
# DICKERSON               24
# CABIN JOHN              18
# ASHTON                  17
# SPENCERVILLE             9
# WASHINGTON GROVE         6
# BRINKLOW                 5
# BARNESVILLE              4
# GLEN ECHO                4
# MOUNT AIRY               3
# LAUREL                   2
# BEALLSVILLE              2
# HYATTSVILLE              1
# KISSIMMEE                1
# Name: City, dtype: int64

# %% [markdown]
# **"SILVER SPRING"** is the city with more non-violent crimes in the Montgomery County.
# How SILVER SPRING is the first in violent crimes ranking, this city is the one with more crimes in the Montgomery County.

# %% [markdown]
# We now check the day of the week and the part of day non-violent crimes mostly occurred.

# %%
crimes_window[crimes.is_violent == False]['datetime_Start'].dt.weekday_name.value_counts()
# Out:
# Friday       3288
# Tuesday      3063
# Wednesday    2993
# Thursday     2969
# Saturday     2870
# Monday       2781
# Sunday       2494
# Name: datetime_Start, dtype: int64

# %%
crimes_window[crimes.is_violent == False]['datetime_Start'].dt.weekday_name.value_counts().plot(kind='bar')

# %%
crimes_window[crimes.is_violent == False].crimes_period.value_counts()
# Out:
# evening      6779
# afternoon    6286
# dawn         3809
# morning      3584
# Name: crimes_period, dtype: int64

# %%
crimes_window[crimes.is_violent == True].crimes_period.value_counts().plot()

# %% [markdown]
# Thus, the day of week where most non-violent events ocurred was **Friday** and the part of the day in which the majority of these crimes took place was the **evening**.

# %% [markdown]
# # 7 Posing and answering our own questions

# %% [markdown]
# We can keep going deeper in the dataset exploration to answer more questions. It could be interesting to take a look
# into the public places and point out in which type of public places most events occurred. To accomplish this, once the location information is mostly abbreviated, it is needed to build a dictionary of the most used public places names and their abbreviations.

# %%
public_places = {
    'ST': 'Street',
    'AVE': 'Avenue',
    'AL': 'Alley',
    'RD': 'Road',
    'DR': 'Drive',
    'PL': 'Pipe Line',
    'TER': 'Terrace',
    'PKW': 'Park Way',
    'BLVD': 'Boulevard',
    'PKWY': 'Park Way',
    'WAY': 'Way',
    'CIR': 'Circle',
    'LN': 'Lawn',
    'CT': 'Court',
    'PIKE': 'Pike',
    'HWY': 'Highway',
}

# %% [markdown]
# This will help us to extract targeted information info from the "Block Address" and thereafter add this to a new column:

# %%
def public_place(c):
    #print(cell)
    for key in public_places.keys():
        if key in str(c).split():
            #print(key+" is in "+c)
            return public_places[key]
    return "other"           

crimes["public_place"] = crimes["Block Address"].apply(public_place)

# %% [markdown]
# With this new information in hands, we can try some more accounting:

# %%
crimes.public_place.value_counts()
# Out:
# Road         6250
# Avenue       4690
# Drive        3930
# Street       1516
# Lawn         1235
# Boulevard    1218
# Court         960
# Pike          763
# Way           620
# Terrace       595
# Pipe Line     483
# Circle        466
# Highway       352
# Park Way      199
# other          92
# Name: public_place, dtype: int64

# %%
crimes.public_place.value_counts().plot(kind='pie')

# %% [markdown]
# Hence, we can see most events in the provided dataset took place in **Roads**, while **Park Ways** were the public locations least susceptible to crimes. As already seen, the most common type of crimes is **"DRIVING UNDER THE INFLUENCE"** and we have just computed that the public place where most crimes occurred is the **Roads**. The strong relationship between this 2 facts is a commonplace.
